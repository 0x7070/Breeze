# %% [markdown]
# ### MISC

# %% [markdown]
# Google Python Docstring template:
#
# ``` python
# def example_func(example_arg: example_type = None) -> example_type:
#   """
#   Short description of the function.
#
#   A more detailed explanation of what the function does, its purpose, and any
#   important behavior or side effects.
#
#   Args:
#       param1 (type): Description of the first parameter.
#       param2 (type): Description of the second parameter.
#
#   Returns:
#       return_type: Description of the return value.
#
#   Raises:
#       ExceptionType: Description of the conditions under which the exception is raised.
#
#   Example:
#       >>> function_name(param1_value, param2_value)
#       expected_output
#   """
#   pass
# ```

# %%
import importlib

a=2
def reload_packages():
  PACKAGES=[
      utils,
      utils.general,
      utils.packets,
      utils.general.helpers,
      utils.packets.feature_extraction,
      utils.packets.handling,
  ]
  print('Reloading packages')
  for package in PACKAGES:
    try:
      print(f'\t- {package.__name__} ... ', end='\n\t  - ')
      importlib.reload(package)
      print('DONE')
    except Exception as e:
      print(f'\t- [!] ERROR loading this item')

reload_packages()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3738949901.py in <cell line: 0>()
#      20       print(f'\t- [!] ERROR loading this item')
#      21
# ---> 22 reload_packages()
#
# /tmp/ipython-input-3738949901.py in reload_packages()
#       7       utils.general,
#       8       utils.packets,
# ----> 9       utils.general.helpers,
#      10       utils.packets.feature_extraction,
#      11       utils.packets.handling,
#
# AttributeError: module 'utils.general' has no attribute 'helpers'

# %% [markdown]
# ---

# %% [markdown]
# # Helper Utilities

# %% [markdown]
# # Feature Extraction Utilities
#
# - `count`
#   - args:
#     - `pcap`:
#       - `Type: scapy.all.PacketList`
#       - PCAP to be counted
#   - defn:
#     - Accepts a PCAP and counts its total
#   - **TO IMPLEMENT**
#     - *Count up TCP, UDP, ICMP, Other*
# - `utc_stamp`
#   - args:
#     - `p`:
#       - `Type: scapy.all.Packet`
#       - Packet to be queried
#   - defn:
#     - Accepts a Packet and pulls its UTC time stamp as a float. Otherwise, `scapy.all.EDecimal`.

# %% [markdown]
# # Packet Handling Utilities

# %% [markdown]
# ---

# %%
# !pip install scapy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.8 MB/s eta 0:00:00
# ...

# %%
#===Imports
from scapy.all import rdpcap, IP, TCP, UDP, DNS, DNSQR

import pandas as pd

from datetime import datatime
#===

#===Globals
#===
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2222555365.py in <cell line: 0>()
#       4 import pandas as pd
#       5
# ----> 6 from datetime import datatime
#       7 #===
#       8
#
# ImportError: cannot import name 'datatime' from 'datetime' (/usr/lib/python3.12/datetime.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Testing zone

# %%
# Out:
# <module 'utils.packets.feature_extraction' from '/content/utils/packets/feature_extraction.py'>

# %%
from utils.packets.feature_extraction import subtract
reload_packages()
# Out:
# Reloading packages
# 	- utils.general.general ...
# 	  - DONE
# 	- utils.packets.feature_extraction ...
# 	  - DONE
# 	- [!] ERROR loading this item
# 	- utils.packets.handling ...
# 	  - DONE
